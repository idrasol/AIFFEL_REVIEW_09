# %% [markdown]
# 제목: 전설의 포켓몬 찾기 일반화 성능 높이기
# ==========================
#
# ## 개요
# 모델 규제 및 하이퍼파라미터 튜닝을 통해서 전설의 포켓몬 찾기 일반화 성능 높이고자 한다.
#
# ### 목차
# 1. 개선
#     1) 유용하지 않을 것 같은 특성 제거 시도
#     2) 모델의 변경
# 2. 주석 및 의견
# 3. Summary
# 4. 회고
# 5. reference

# %% [markdown]
# 개선
# ----------

# %% [markdown]
# ### 유용하지 않을 것 같은 특성 제거
# 1. 상관관계를 분석해본다
# 2. 인터넷으로 포켓몬 게임에서의 전설의 포켓몬 특징을 교차 검증해본다

# %% [markdown]
# #### 상관관계 분석

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
original_data = pd.read_csv('Pokemon.csv')

# %%
pokemon = original_data.copy()
pokemon.tail()
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %%
# 공백만 제거하고 이름 길이 추가
pokemon["Name"] = pokemon["Name"].apply(lambda i: i.replace(" ", ""))
pokemon["name_count"] = pokemon["Name"].apply(lambda i: len(i))

# %%
pokemon.tail()
# Out:
#        #                Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719             Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMegaDiancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopaConfined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopaUnbound  Psychic   Dark    680  80     160       60
# 799  721           Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  name_count
# 795      100      150     50           6       True           7
# 796      160      110    110           6       True          18
# 797      150      130     70           6       True          18
# 798      170      130     80           6       True          17
# 799      130       90     70           6       True           9

# %%
# 상관관계 조사를 위해서 숫자 칼럼만 남김
features = ['Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary', 'name_count']
pokemon_corr = pokemon[features]
pokemon_corr
# Out:
#      Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# 0      318  45      49       49       65       65     45           1
# 1      405  60      62       63       80       80     60           1
# 2      525  80      82       83      100      100     80           1
# 3      625  80     100      123      122      120     80           1
# 4      309  39      52       43       60       50     65           1
# ..     ...  ..     ...      ...      ...      ...    ...         ...
# 795    600  50     100      150      100      150     50           6
# 796    700  50     160      110      160      110    110           6
# 797    600  80     110       60      150      130     70           6
# 798    680  80     160       60      170      130     80           6
# 799    600  80     110      120      130       90     70           6
#
#      Legendary  name_count
# 0        False           9
# 1        False           7
# 2        False           8
# 3        False          20
# 4        False          10
# ..         ...         ...
# 795       True           7
# 796       True          18
# 797       True          18
# 798       True          17
# 799       True           9
#
# [800 rows x 10 columns]

# %%
data = pokemon_corr.corr()
data
# Out:
#                Total        HP    Attack   Defense   Sp. Atk   Sp. Def  \
# Total       1.000000  0.618748  0.736211  0.612787  0.747250  0.717609
# HP          0.618748  1.000000  0.422386  0.239622  0.362380  0.378718
# Attack      0.736211  0.422386  1.000000  0.438687  0.396362  0.263990
# Defense     0.612787  0.239622  0.438687  1.000000  0.223549  0.510747
# Sp. Atk     0.747250  0.362380  0.396362  0.223549  1.000000  0.506121
# Sp. Def     0.717609  0.378718  0.263990  0.510747  0.506121  1.000000
# Speed       0.575943  0.175952  0.381240  0.015227  0.473018  0.259133
# Generation  0.048384  0.058683  0.051451  0.042419  0.036437  0.028486
# Legendary   0.501758  0.273620  0.345408  0.246377  0.448907  0.363937
# name_count  0.480152  0.185767  0.412561  0.309320  0.397248  0.310635
#
#                Speed  Generation  Legendary  name_count
# Total       0.575943    0.048384   0.501758    0.480152
# HP          0.175952    0.058683   0.273620    0.185767
# Attack      0.381240    0.051451   0.345408    0.412561
# Defense     0.015227    0.042419   0.246377    0.309320
# Sp. Atk     0.473018    0.036437   0.448907    0.397248
# Sp. Def     0.259133    0.028486   0.363937    0.310635
# Speed       1.000000   -0.023121   0.326715    0.281384
# Generation -0.023121    1.000000   0.079794    0.074817
# Legendary   0.326715    0.079794   1.000000    0.211952
# name_count  0.281384    0.074817   0.211952    1.000000

# %%
# seaborn 0.12 버전이 오류가 있어서 히트맵에 숫자가 안떴음. 0.13.2로 업그레이드 함
plt.figure(figsize=(5,5))
mask = np.zeros_like(data, dtype=bool) # 히트맵 절반만 표시하기 위함
mask[np.triu_indices_from(mask)] = True 
sns.heatmap(data, mask=mask, annot=True, fmt = '.2f', cmap="coolwarm", annot_kws={"size": 8}, linewidths=0.5)
plt.show()

# %% [markdown]
# #### 사전조사
#
# ##### 인터넷으로 조사한 포켓몬 게임에서 전설의 포켓몬 특징(출처: ChatGPT)
# 1. 높은 기본 능력치
# 2. 고유한 기술
# 3. 시그니처 무브먼트
# 4. 희귀성
# 5. 게임의 메인스토리 연관성
#
# ##### 위 상관관계 분석에서 도출된 내용
# 1. 총 능력치와 높은 상관관계를 보임
# 2. Sp. Atk과 높은 상관관계를 보임
#
# ##### 적용
# * 훈련 데이터를 더욱 압축해서 상관관계가 높은 2개만 가지고 훈련해본다

# %%
features_corr = ['Total', 'Sp. Atk']
target = 'Legendary'

# %%
X = original_data[features_corr]
print(X.shape)
X.head()
# Out:
# (800, 2)
#    Total  Sp. Atk
# 0    318       65
# 1    405       80
# 2    525      100
# 3    625      122
# 4    309       60

# %%
y = original_data[target]
print(y.shape)
y.tail()
# Out:
# (800,)
# 795    True
# 796    True
# 797    True
# 798    True
# 799    True
# Name: Legendary, dtype: bool

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (640, 2) (640,)
# (160, 2) (160,)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

model = DecisionTreeClassifier(random_state=25)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

confu_matrix_ratio = confusion_matrix(y_test, y_pred)
print(confu_matrix_ratio)
print(f'디시전트리 모델 정확도: {(confu_matrix_ratio[0][0]+confu_matrix_ratio[1][1])/confu_matrix_ratio.sum()}')
# Out:
# [[143   4]
#  [  2  11]]
# 디시전트리 모델 정확도: 0.9625

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.99      0.97      0.98       147
#         True       0.73      0.85      0.79        13
#
#     accuracy                           0.96       160
#    macro avg       0.86      0.91      0.88       160
# weighted avg       0.97      0.96      0.96       160

# %% [markdown]
# #### <유용하지 않을 것 같은 특성 제거 시도> 결과
# 1. 디시전트리 매트릭스 모델 정확도: 95.625% → 96.25%로 0.625%p 개선됨
# 2. recall 수치: 92% → 85%로 하락함
#    - 이것은 FN 값이 이전 데이터 세트로 훈련했을 때 1이었는데, 2로 증가하면서 영향을 미친 것 같음
#
# #### 결론
# 1. 전설의 포켓몬을 찾아야 하는 것이 목표이기 때문에 모델의 정확도는 개선되었으나, recall 수치가 하락하여 전설의 포켓몬을 찾는 확률이 오히려 떨어졌으므로 다른 개선 방법이 필요하다는 의견임

# %% [markdown]
# ### 훈련 모델의 변경
# 1. 4장 집 값 모델을 적용해본다? 왜?
#     - 주어진 데이터가 집 값의 예측 모델에서처럼 다양한 요소들로 이루어진 테이블임
#     - 인터넷 조사와 상관관계 분석상 각각의 요소들이 완전히 무관하지는 않음
#     - 결과 값만 binary하게 나오게 튜닝하면 될 듯

# %% [markdown]
# #### 훈련 모델의 변경
#
# ##### 데이터준비 - 벡터화

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %%
pokemon = original_data.copy()

# 공백만 제거하고 이름 길이 추가
pokemon["Name"] = pokemon["Name"].apply(lambda i: i.replace(" ", "")) 
pokemon["name_count"] = pokemon["Name"].apply(lambda i: len(i))

# %%
features = ['Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'name_count']
target = 'Legendary'

# %%
X = pokemon[features]
print(X.shape)
X.head()
# Out:
# (800, 9)
#    Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  name_count
# 0    318  45      49       49       65       65     45           1           9
# 1    405  60      62       63       80       80     60           1           7
# 2    525  80      82       83      100      100     80           1           8
# 3    625  80     100      123      122      120     80           1          20
# 4    309  39      52       43       60       50     65           1          10

# %%
y = pokemon[target]
print(y.shape)
y.tail()
# Out:
# (800,)
# 795    True
# 796    True
# 797    True
# 798    True
# 799    True
# Name: Legendary, dtype: bool

# %% [markdown]
# ##### 평가 방법 선택 - 홀드아웃

# %%
# 데이터가 충분하지 않으므로 반복 K-겹 교차 검증을 추후에 시도할 예정임

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (640, 9) (640,)
# (160, 9) (160,)

# %%
y_train
# Out:
# 300    False
# 351    False
# 193    False
# 794     True
# 798     True
#        ...
# 156     True
# 384    False
# 645    False
# 757    False
# 456    False
# Name: Legendary, Length: 640, dtype: bool

# %%
X_train
# Out:
#      Total   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# 300    430   60      85       60       50       50    125           3
# 351    500  170      90       45       90       45     60           3
# 193    280   55      40       40       65       45     35           2
# 794    600  108     100      121       81       95     95           6
# 798    680   80     160       60      170      130     80           6
# ..     ...  ...     ...      ...      ...      ...    ...         ...
# 156    580   90      85      100       95      125     85           1
# 384    440   60      90       70       60      120     40           3
# 645    535   71      95       85      110       95     79           5
# 757    482   86      92       88       68       75     73           6
# 456    495   60      52      168       47      138     30           4
#
#      name_count
# 300           7
# 351           7
# 193           6
# 794          15
# 798          17
# ..          ...
# 156           8
# 384           7
# 645           9
# 757           7
# 456           9
#
# [640 rows x 9 columns]

# %% [markdown]
# ##### 데이터준비 - 정규화

# %%
mean = X_train.mean(axis=0)
X_train -= mean
std = X_train.std(axis=0)
X_train /= std
X_test -= mean
X_test /= std

# %% [markdown]
# ##### 기준모델 - 통계적 검정력을 달성하는 모델 만들기

# %%
# 입력층과 출력층으로만 심플하게 구성

def build_model():
    model = keras.Sequential([
        layers.Dense(16, activation="relu"),
        layers.Dense(1, activation="sigmoid")  # 이진 값으로 변경
    ])
    model.compile(optimizer="rmsprop", loss="binary_crossentropy", metrics=["accuracy"]) # 손실함수는 이진함수로 넣고, 평가지표는 정확도로 함
    return model

# %%
model = build_model()
history = model.fit(X_train, y_train,
                    epochs=20, batch_size=50, 
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.3005 - loss: 0.8889 - val_accuracy: 0.3000 - val_loss: 0.7957
# Epoch 2/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3912 - loss: 0.7831 - val_accuracy: 0.4000 - val_loss: 0.7298
# Epoch 3/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4385 - loss: 0.7260 - val_accuracy: 0.5063 - val_loss: 0.6737
# Epoch 4/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5283 - loss: 0.7035 - val_accuracy: 0.7188 - val_loss: 0.6242
# Epoch 5/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6849 - loss: 0.6464 - val_accuracy: 0.8125 - val_loss: 0.5797
# Epoch 6/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7942 - loss: 0.6024 - val_accuracy: 0.8313 - val_loss: 0.5398
# Epoch 7/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8450 - loss: 0.5550 - val_accuracy: 0.8500 - val_loss: 0.5031
# Epoch 8/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8658 - loss: 0.5140 - val_accuracy: 0.8750 - val_loss: 0.4699
# Epoch 9/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8831 - loss: 0.4887 - val_accuracy: 0.9062 - val_loss: 0.4387
# Epoch 10/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8868 - loss: 0.4553 - val_accuracy: 0.9187 - val_loss: 0.4102
# Epoch 11/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9024 - loss: 0.4304 - val_accuracy: 0.9250 - val_loss: 0.3839
# Epoch 12/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8917 - loss: 0.4054 - val_accuracy: 0.9312 - val_loss: 0.3599
# Epoch 13/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9229 - loss: 0.3554 - val_accuracy: 0.9250 - val_loss: 0.3383
# Epoch 14/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9333 - loss: 0.3323 - val_accuracy: 0.9250 - val_loss: 0.3180
# Epoch 15/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9237 - loss: 0.3344 - val_accuracy: 0.9250 - val_loss: 0.2998
# Epoch 16/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9385 - loss: 0.3020 - val_accuracy: 0.9312 - val_loss: 0.2840
# Epoch 17/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9347 - loss: 0.2809 - val_accuracy: 0.9375 - val_loss: 0.2699
# Epoch 18/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9293 - loss: 0.2743 - val_accuracy: 0.9375 - val_loss: 0.2574
# Epoch 19/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9303 - loss: 0.2654 - val_accuracy: 0.9438 - val_loss: 0.2457
# Epoch 20/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9251 - loss: 0.2624 - val_accuracy: 0.9438 - val_loss: 0.2349

# %% [markdown]
# ##### 기준 모델: 통계적 검정력 달성 여부
# - 오리지널 데이터에서 일반 포켓몬 맞출 수 있는 확률: 0.91875
# - 검증 정확도: 0.9438
# - 결론: 아주 간단한 기준점은 넘은 것 같음

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
history_dict = history.history
loss_values = history_dict["loss"]
val_loss_values = history_dict["val_loss"]
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, "bo", label="Training loss")
plt.plot(epochs, val_loss_values, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.clf()
acc = history_dict["accuracy"]
val_acc = history_dict["val_accuracy"]
plt.plot(epochs, acc, "bo", label="Training acc")
plt.plot(epochs, val_acc, "b", label="Validation acc")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# ##### 과대적합 모델 만들기
# 1. 층 추가
# 2. 층 크기 키우기
# 3. 더 많은 에포크 훈련

# %%
def build_model_overfit():
    model = keras.Sequential([
        layers.Dense(128, activation="relu"),
        layers.Dense(128, activation="relu"),
        layers.Dense(1, activation="sigmoid")  # 이진 값으로 변경
    ])
    model.compile(optimizer="rmsprop", loss="binary_crossentropy", metrics=["accuracy"]) # 손실함수는 이진함수로 넣고, 평가지표는 정확도로 함
    return model

# %%
model = build_model_overfit()
history = model.fit(X_train, y_train,
                    epochs=200, batch_size=50, 
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8723 - loss: 0.4406 - val_accuracy: 0.9187 - val_loss: 0.2500
# Epoch 2/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9222 - loss: 0.2260 - val_accuracy: 0.9187 - val_loss: 0.1892
# Epoch 3/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9441 - loss: 0.1643 - val_accuracy: 0.9312 - val_loss: 0.1549
# Epoch 4/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9433 - loss: 0.1550 - val_accuracy: 0.9312 - val_loss: 0.1387
# Epoch 5/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9533 - loss: 0.1158 - val_accuracy: 0.9375 - val_loss: 0.1318
# Epoch 6/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9659 - loss: 0.1004 - val_accuracy: 0.9375 - val_loss: 0.1209
# Epoch 7/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9603 - loss: 0.0972 - val_accuracy: 0.9438 - val_loss: 0.1144
# Epoch 8/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9735 - loss: 0.0784 - val_accuracy: 0.9500 - val_loss: 0.1116
# Epoch 9/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9665 - loss: 0.0861 - val_accuracy: 0.9438 - val_loss: 0.1066
# Epoch 10/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9511 - loss: 0.0973 - val_accuracy: 0.9438 - val_loss: 0.1043
# Epoch 11/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9662 - loss: 0.0808 - val_accuracy: 0.9500 - val_loss: 0.1012
# Epoch 12/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9709 - loss: 0.0689 - val_accuracy: 0.9375 - val_loss: 0.1054
# Epoch 13/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9596 - loss: 0.0825 - val_accuracy: 0.9438 - val_loss: 0.0963
# Epoch 14/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9787 - loss: 0.0624 - val_accuracy: 0.9438 - val_loss: 0.1005
# Epoch 15/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9769 - loss: 0.0583 - val_accuracy: 0.9500 - val_loss: 0.0931
# Epoch 16/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9703 - loss: 0.0669 - val_accuracy: 0.9563 - val_loss: 0.0891
# Epoch 17/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9756 - loss: 0.0610 - val_accuracy: 0.9500 - val_loss: 0.0894
# Epoch 18/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9718 - loss: 0.0667 - val_accuracy: 0.9563 - val_loss: 0.0901
# Epoch 19/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9791 - loss: 0.0592 - val_accuracy: 0.9563 - val_loss: 0.0940
# Epoch 20/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9675 - loss: 0.0713 - val_accuracy: 0.9563 - val_loss: 0.0937
# Epoch 21/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9842 - loss: 0.0537 - val_accuracy: 0.9625 - val_loss: 0.0905
# Epoch 22/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9823 - loss: 0.0424 - val_accuracy: 0.9625 - val_loss: 0.0897
# Epoch 23/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9929 - loss: 0.0402 - val_accuracy: 0.9563 - val_loss: 0.0836
# Epoch 24/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9830 - loss: 0.0455 - val_accuracy: 0.9563 - val_loss: 0.0841
# Epoch 25/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9807 - loss: 0.0483 - val_accuracy: 0.9563 - val_loss: 0.0898
# Epoch 26/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9858 - loss: 0.0509 - val_accuracy: 0.9625 - val_loss: 0.0798
# Epoch 27/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9846 - loss: 0.0455 - val_accuracy: 0.9625 - val_loss: 0.0959
# Epoch 28/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9866 - loss: 0.0383 - val_accuracy: 0.9625 - val_loss: 0.0795
# Epoch 29/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9891 - loss: 0.0368 - val_accuracy: 0.9625 - val_loss: 0.0811
# Epoch 30/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9850 - loss: 0.0368 - val_accuracy: 0.9625 - val_loss: 0.0836
# Epoch 31/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9793 - loss: 0.0442 - val_accuracy: 0.9563 - val_loss: 0.0850
# Epoch 32/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9752 - loss: 0.0560 - val_accuracy: 0.9563 - val_loss: 0.0829
# Epoch 33/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9906 - loss: 0.0334 - val_accuracy: 0.9625 - val_loss: 0.0830
# Epoch 34/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9885 - loss: 0.0411 - val_accuracy: 0.9625 - val_loss: 0.0880
# Epoch 35/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9818 - loss: 0.0374 - val_accuracy: 0.9688 - val_loss: 0.0914
# Epoch 36/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9900 - loss: 0.0301 - val_accuracy: 0.9625 - val_loss: 0.0907
# Epoch 37/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9899 - loss: 0.0321 - val_accuracy: 0.9563 - val_loss: 0.0840
# Epoch 38/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9847 - loss: 0.0387 - val_accuracy: 0.9563 - val_loss: 0.0853
# Epoch 39/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9929 - loss: 0.0254 - val_accuracy: 0.9688 - val_loss: 0.0883
# Epoch 40/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9886 - loss: 0.0283 - val_accuracy: 0.9563 - val_loss: 0.0848
# Epoch 41/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9953 - loss: 0.0294 - val_accuracy: 0.9625 - val_loss: 0.0842
# Epoch 42/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9911 - loss: 0.0279 - val_accuracy: 0.9688 - val_loss: 0.0911
# Epoch 43/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9907 - loss: 0.0312 - val_accuracy: 0.9625 - val_loss: 0.0808
# Epoch 44/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9905 - loss: 0.0275 - val_accuracy: 0.9563 - val_loss: 0.0834
# Epoch 45/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9939 - loss: 0.0252 - val_accuracy: 0.9688 - val_loss: 0.0968
# Epoch 46/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9900 - loss: 0.0250 - val_accuracy: 0.9563 - val_loss: 0.0909
# Epoch 47/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9967 - loss: 0.0200 - val_accuracy: 0.9688 - val_loss: 0.0923
# Epoch 48/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9920 - loss: 0.0230 - val_accuracy: 0.9563 - val_loss: 0.0855
# Epoch 49/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9877 - loss: 0.0293 - val_accuracy: 0.9563 - val_loss: 0.0860
# Epoch 50/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9918 - loss: 0.0263 - val_accuracy: 0.9625 - val_loss: 0.0858
# Epoch 51/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9952 - loss: 0.0234 - val_accuracy: 0.9563 - val_loss: 0.0894
# Epoch 52/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9943 - loss: 0.0232 - val_accuracy: 0.9688 - val_loss: 0.0894
# Epoch 53/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9882 - loss: 0.0287 - val_accuracy: 0.9563 - val_loss: 0.0874
# Epoch 54/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9947 - loss: 0.0232 - val_accuracy: 0.9563 - val_loss: 0.0883
# Epoch 55/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9844 - loss: 0.0272 - val_accuracy: 0.9750 - val_loss: 0.0941
# Epoch 56/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9929 - loss: 0.0204 - val_accuracy: 0.9625 - val_loss: 0.0911
# Epoch 57/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9866 - loss: 0.0287 - val_accuracy: 0.9750 - val_loss: 0.0924
# Epoch 58/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9922 - loss: 0.0210 - val_accuracy: 0.9563 - val_loss: 0.0955
# Epoch 59/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9956 - loss: 0.0175 - val_accuracy: 0.9563 - val_loss: 0.0948
# Epoch 60/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9890 - loss: 0.0181 - val_accuracy: 0.9688 - val_loss: 0.0967
# Epoch 61/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9963 - loss: 0.0139 - val_accuracy: 0.9688 - val_loss: 0.1071
# Epoch 62/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9932 - loss: 0.0192 - val_accuracy: 0.9563 - val_loss: 0.0991
# Epoch 63/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9961 - loss: 0.0141 - val_accuracy: 0.9625 - val_loss: 0.1032
# Epoch 64/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9912 - loss: 0.0220 - val_accuracy: 0.9625 - val_loss: 0.1115
# Epoch 65/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9891 - loss: 0.0210 - val_accuracy: 0.9625 - val_loss: 0.1048
# Epoch 66/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9924 - loss: 0.0170 - val_accuracy: 0.9563 - val_loss: 0.1060
# Epoch 67/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9923 - loss: 0.0199 - val_accuracy: 0.9625 - val_loss: 0.1019
# Epoch 68/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9907 - loss: 0.0162 - val_accuracy: 0.9688 - val_loss: 0.1098
# Epoch 69/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9944 - loss: 0.0134 - val_accuracy: 0.9625 - val_loss: 0.1051
# Epoch 70/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9927 - loss: 0.0143 - val_accuracy: 0.9625 - val_loss: 0.1018
# Epoch 71/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9969 - loss: 0.0104 - val_accuracy: 0.9625 - val_loss: 0.1016
# Epoch 72/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9971 - loss: 0.0138 - val_accuracy: 0.9625 - val_loss: 0.1086
# Epoch 73/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9890 - loss: 0.0227 - val_accuracy: 0.9625 - val_loss: 0.1076
# Epoch 74/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9934 - loss: 0.0165 - val_accuracy: 0.9625 - val_loss: 0.1099
# Epoch 75/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9918 - loss: 0.0161 - val_accuracy: 0.9625 - val_loss: 0.1102
# Epoch 76/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9937 - loss: 0.0164 - val_accuracy: 0.9563 - val_loss: 0.1092
# Epoch 77/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9944 - loss: 0.0167 - val_accuracy: 0.9563 - val_loss: 0.1095
# Epoch 78/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9973 - loss: 0.0138 - val_accuracy: 0.9625 - val_loss: 0.1132
# Epoch 79/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9929 - loss: 0.0164 - val_accuracy: 0.9625 - val_loss: 0.1114
# Epoch 80/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9963 - loss: 0.0138 - val_accuracy: 0.9625 - val_loss: 0.1139
# Epoch 81/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9985 - loss: 0.0101 - val_accuracy: 0.9563 - val_loss: 0.1137
# Epoch 82/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9992 - loss: 0.0076 - val_accuracy: 0.9625 - val_loss: 0.1124
# Epoch 83/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9959 - loss: 0.0094 - val_accuracy: 0.9625 - val_loss: 0.1146
# Epoch 84/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9988 - loss: 0.0059 - val_accuracy: 0.9688 - val_loss: 0.1202
# Epoch 85/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9896 - loss: 0.0207 - val_accuracy: 0.9625 - val_loss: 0.1159
# Epoch 86/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9986 - loss: 0.0106 - val_accuracy: 0.9688 - val_loss: 0.1212
# Epoch 87/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9938 - loss: 0.0123 - val_accuracy: 0.9625 - val_loss: 0.1185
# Epoch 88/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9952 - loss: 0.0096 - val_accuracy: 0.9625 - val_loss: 0.1163
# Epoch 89/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9977 - loss: 0.0096 - val_accuracy: 0.9563 - val_loss: 0.1223
# Epoch 90/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9981 - loss: 0.0081 - val_accuracy: 0.9625 - val_loss: 0.1201
# Epoch 91/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9981 - loss: 0.0054 - val_accuracy: 0.9625 - val_loss: 0.1236
# Epoch 92/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9983 - loss: 0.0083 - val_accuracy: 0.9625 - val_loss: 0.1257
# Epoch 93/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9997 - loss: 0.0075 - val_accuracy: 0.9563 - val_loss: 0.1313
# Epoch 94/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9980 - loss: 0.0071 - val_accuracy: 0.9625 - val_loss: 0.1246
# Epoch 95/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9983 - loss: 0.0057 - val_accuracy: 0.9563 - val_loss: 0.1235
# Epoch 96/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9987 - loss: 0.0051 - val_accuracy: 0.9625 - val_loss: 0.1208
# Epoch 97/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9986 - loss: 0.0063 - val_accuracy: 0.9625 - val_loss: 0.1225
# Epoch 98/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9998 - loss: 0.0074 - val_accuracy: 0.9625 - val_loss: 0.1268
# Epoch 99/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9983 - loss: 0.0055 - val_accuracy: 0.9750 - val_loss: 0.1317
# Epoch 100/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9997 - loss: 0.0063 - val_accuracy: 0.9750 - val_loss: 0.1274
# Epoch 101/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9966 - loss: 0.0067 - val_accuracy: 0.9625 - val_loss: 0.1259
# Epoch 102/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.9625 - val_loss: 0.1307
# Epoch 103/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9997 - loss: 0.0038 - val_accuracy: 0.9563 - val_loss: 0.1373
# Epoch 104/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9971 - loss: 0.0052 - val_accuracy: 0.9625 - val_loss: 0.1336
# Epoch 105/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.9625 - val_loss: 0.1306
# Epoch 106/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9997 - loss: 0.0052 - val_accuracy: 0.9688 - val_loss: 0.1403
# Epoch 107/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.9563 - val_loss: 0.1379
# Epoch 108/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9992 - loss: 0.0056 - val_accuracy: 0.9625 - val_loss: 0.1295
# Epoch 109/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.9625 - val_loss: 0.1326
# Epoch 110/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.9500 - val_loss: 0.1370
# Epoch 111/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.9750 - val_loss: 0.1433
# Epoch 112/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9989 - loss: 0.0031 - val_accuracy: 0.9688 - val_loss: 0.1361
# Epoch 113/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.9688 - val_loss: 0.1334
# Epoch 114/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9688 - val_loss: 0.1407
# Epoch 115/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9625 - val_loss: 0.1342
# Epoch 116/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9625 - val_loss: 0.1375
# Epoch 117/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.9625 - val_loss: 0.1433
# Epoch 118/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.9625 - val_loss: 0.1419
# Epoch 119/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9688 - val_loss: 0.1601
# Epoch 120/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.9688 - val_loss: 0.1538
# Epoch 121/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9998 - loss: 0.0020 - val_accuracy: 0.9563 - val_loss: 0.1496
# Epoch 122/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9625 - val_loss: 0.1482
# Epoch 123/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9688 - val_loss: 0.1525
# Epoch 124/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9625 - val_loss: 0.1546
# Epoch 125/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9750 - val_loss: 0.1674
# Epoch 126/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9625 - val_loss: 0.1509
# Epoch 127/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9688 - val_loss: 0.1488
# Epoch 128/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9625 - val_loss: 0.1494
# Epoch 129/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9975 - loss: 0.0040 - val_accuracy: 0.9625 - val_loss: 0.1486
# Epoch 130/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.9625 - val_loss: 0.1544
# Epoch 131/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9688 - val_loss: 0.1502
# Epoch 132/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9688 - val_loss: 0.1748
# Epoch 133/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9750 - val_loss: 0.1602
# Epoch 134/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9625 - val_loss: 0.1533
# Epoch 135/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9625 - val_loss: 0.1528
# Epoch 136/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9688 - val_loss: 0.1595
# Epoch 137/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 9.3826e-04 - val_accuracy: 0.9688 - val_loss: 0.1692
# Epoch 138/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 9.4438e-04 - val_accuracy: 0.9750 - val_loss: 0.1735
# Epoch 139/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9625 - val_loss: 0.1564
# Epoch 140/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 9.2259e-04 - val_accuracy: 0.9688 - val_loss: 0.1590
# Epoch 141/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 9.0520e-04 - val_accuracy: 0.9688 - val_loss: 0.1558
# Epoch 142/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9688 - val_loss: 0.1627
# Epoch 143/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 9.0604e-04 - val_accuracy: 0.9625 - val_loss: 0.1575
# Epoch 144/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 9.0701e-04 - val_accuracy: 0.9688 - val_loss: 0.1630
# Epoch 145/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9625 - val_loss: 0.1894
# Epoch 146/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 8.8411e-04 - val_accuracy: 0.9625 - val_loss: 0.1654
# Epoch 147/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9688 - val_loss: 0.1778
# Epoch 148/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9688 - val_loss: 0.1696
# Epoch 149/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 7.7182e-04 - val_accuracy: 0.9750 - val_loss: 0.1774
# Epoch 150/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9750 - val_loss: 0.1768
# Epoch 151/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 8.2483e-04 - val_accuracy: 0.9688 - val_loss: 0.1788
# Epoch 152/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9688 - val_loss: 0.1754
# Epoch 153/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 9.4683e-04 - val_accuracy: 0.9688 - val_loss: 0.1764
# Epoch 154/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 7.2963e-04 - val_accuracy: 0.9688 - val_loss: 0.1700
# Epoch 155/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 5.9613e-04 - val_accuracy: 0.9563 - val_loss: 0.2303
# Epoch 156/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9750 - val_loss: 0.1747
# Epoch 157/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 7.2885e-04 - val_accuracy: 0.9688 - val_loss: 0.1758
# Epoch 158/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 6.1275e-04 - val_accuracy: 0.9625 - val_loss: 0.1744
# Epoch 159/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 6.1246e-04 - val_accuracy: 0.9688 - val_loss: 0.1840
# Epoch 160/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 4.5364e-04 - val_accuracy: 0.9625 - val_loss: 0.1780
# Epoch 161/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 7.2059e-04 - val_accuracy: 0.9750 - val_loss: 0.1919
# Epoch 162/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 8.7682e-04 - val_accuracy: 0.9688 - val_loss: 0.1828
# Epoch 163/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 6.1303e-04 - val_accuracy: 0.9688 - val_loss: 0.1911
# Epoch 164/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 5.4438e-04 - val_accuracy: 0.9688 - val_loss: 0.1918
# Epoch 165/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 4.9820e-04 - val_accuracy: 0.9625 - val_loss: 0.1826
# Epoch 166/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 5.1115e-04 - val_accuracy: 0.9625 - val_loss: 0.1881
# Epoch 167/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 4.5082e-04 - val_accuracy: 0.9688 - val_loss: 0.1941
# Epoch 168/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 2.9961e-04 - val_accuracy: 0.9563 - val_loss: 0.1930
# Epoch 169/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 8.6998e-04 - val_accuracy: 0.9688 - val_loss: 0.1967
# Epoch 170/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 6.4794e-04 - val_accuracy: 0.9688 - val_loss: 0.1980
# Epoch 171/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 2.6262e-04 - val_accuracy: 0.9500 - val_loss: 0.1971
# Epoch 172/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9688 - val_loss: 0.1966
# Epoch 173/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 2.6642e-04 - val_accuracy: 0.9688 - val_loss: 0.1960
# Epoch 174/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 2.0855e-04 - val_accuracy: 0.9625 - val_loss: 0.1921
# Epoch 175/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 3.5608e-04 - val_accuracy: 0.9688 - val_loss: 0.1998
# Epoch 176/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 2.4553e-04 - val_accuracy: 0.9625 - val_loss: 0.1940
# Epoch 177/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 6.1304e-04 - val_accuracy: 0.9750 - val_loss: 0.2070
# Epoch 178/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 3.7387e-04 - val_accuracy: 0.9750 - val_loss: 0.2033
# Epoch 179/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 1.9913e-04 - val_accuracy: 0.9750 - val_loss: 0.2156
# Epoch 180/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 3.0771e-04 - val_accuracy: 0.9688 - val_loss: 0.2012
# Epoch 181/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 2.6315e-04 - val_accuracy: 0.9750 - val_loss: 0.2020
# Epoch 182/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 1.9841e-04 - val_accuracy: 0.9688 - val_loss: 0.1897
# Epoch 183/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 4.7227e-04 - val_accuracy: 0.9750 - val_loss: 0.2092
# Epoch 184/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 2.3049e-04 - val_accuracy: 0.9688 - val_loss: 0.2072
# Epoch 185/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 1.8388e-04 - val_accuracy: 0.9688 - val_loss: 0.1951
# Epoch 186/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.4250e-04 - val_accuracy: 0.9625 - val_loss: 0.1973
# Epoch 187/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 5.1860e-04 - val_accuracy: 0.9750 - val_loss: 0.2042
# Epoch 188/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.2373e-04 - val_accuracy: 0.9750 - val_loss: 0.2131
# Epoch 189/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 3.7530e-04 - val_accuracy: 0.9750 - val_loss: 0.2011
# Epoch 190/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 1.6735e-04 - val_accuracy: 0.9688 - val_loss: 0.1922
# Epoch 191/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 1.9614e-04 - val_accuracy: 0.9750 - val_loss: 0.2191
# Epoch 192/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 2.6119e-04 - val_accuracy: 0.9750 - val_loss: 0.2128
# Epoch 193/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 1.9671e-04 - val_accuracy: 0.9688 - val_loss: 0.2070
# Epoch 194/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 1.6196e-04 - val_accuracy: 0.9688 - val_loss: 0.2125
# Epoch 195/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 1.5170e-04 - val_accuracy: 0.9688 - val_loss: 0.2022
# Epoch 196/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 2.4582e-04 - val_accuracy: 0.9688 - val_loss: 0.2102
# Epoch 197/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 1.3655e-04 - val_accuracy: 0.9688 - val_loss: 0.2010
# Epoch 198/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 2.2157e-04 - val_accuracy: 0.9750 - val_loss: 0.2188
# Epoch 199/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 3.0237e-04 - val_accuracy: 0.9750 - val_loss: 0.2161
# Epoch 200/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 1.2998e-04 - val_accuracy: 0.9750 - val_loss: 0.2278

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
history_dict = history.history
loss_values = history_dict["loss"]
val_loss_values = history_dict["val_loss"]
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, "bo", label="Training loss")
plt.plot(epochs, val_loss_values, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.clf()
acc = history_dict["accuracy"]
val_acc = history_dict["val_accuracy"]
plt.plot(epochs, acc, "bo", label="Training acc")
plt.plot(epochs, val_acc, "b", label="Validation acc")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# ##### 26 에포크부터는 검증손실이 떨어지지 않고 다시 오르는 상황
# - 과대적합 모델이 잘 만들어진 것 같음
# - 정확도는 26 에포크에서 0.9625로 오리지널 데이터에서 일반 포켓몬 맞출 수 있는 확률(0.91875)이나, 기준 모델 검증 정확도(0.9438) 보다는 향상되었으나, 디시전트리 검증 정확도(0.9625)보다는 더 개선되지는 않았음
#
# ##### 일반화 성능 최대화 시도
# - 에포크 줄이기
# - 하이퍼파라미터 변경: 층 크기 변경하기
# - L2 규제 적용
# - 유용하지 않을 것 같은 특성까지 결합해보기

# %%
def build_model_fit():
    model = keras.Sequential([
        layers.Dense(512, activation="relu"),
        layers.Dense(512, activation="relu"),
        layers.Dense(1, activation="sigmoid")  # 이진 값으로 변경
    ])
    model.compile(optimizer="rmsprop", loss="binary_crossentropy", metrics=["accuracy"]) # 손실함수는 이진함수로 넣고, 평가지표는 정확도로 함
    return model

# %%
model = build_model_fit()
history = model.fit(X_train, y_train,
                    epochs=30, batch_size=50, 
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.8000 - loss: 0.3988 - val_accuracy: 0.9187 - val_loss: 0.1948
# Epoch 2/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9428 - loss: 0.1546 - val_accuracy: 0.9312 - val_loss: 0.1483
# Epoch 3/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9539 - loss: 0.1313 - val_accuracy: 0.9375 - val_loss: 0.1228
# Epoch 4/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9556 - loss: 0.1194 - val_accuracy: 0.9250 - val_loss: 0.1245
# Epoch 5/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9642 - loss: 0.1014 - val_accuracy: 0.9500 - val_loss: 0.1136
# Epoch 6/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9607 - loss: 0.1059 - val_accuracy: 0.9500 - val_loss: 0.1050
# Epoch 7/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9604 - loss: 0.0959 - val_accuracy: 0.9438 - val_loss: 0.1097
# Epoch 8/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9657 - loss: 0.0758 - val_accuracy: 0.9438 - val_loss: 0.1034
# Epoch 9/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9786 - loss: 0.0582 - val_accuracy: 0.9500 - val_loss: 0.1036
# Epoch 10/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9825 - loss: 0.0542 - val_accuracy: 0.9500 - val_loss: 0.1003
# Epoch 11/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9697 - loss: 0.0642 - val_accuracy: 0.9500 - val_loss: 0.0997
# Epoch 12/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9799 - loss: 0.0512 - val_accuracy: 0.9500 - val_loss: 0.0903
# Epoch 13/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9756 - loss: 0.0699 - val_accuracy: 0.9563 - val_loss: 0.0963
# Epoch 14/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9775 - loss: 0.0483 - val_accuracy: 0.9563 - val_loss: 0.0933
# Epoch 15/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9777 - loss: 0.0591 - val_accuracy: 0.9688 - val_loss: 0.0841
# Epoch 16/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9882 - loss: 0.0448 - val_accuracy: 0.9563 - val_loss: 0.1205
# Epoch 17/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9836 - loss: 0.0424 - val_accuracy: 0.9625 - val_loss: 0.0876
# Epoch 18/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9888 - loss: 0.0334 - val_accuracy: 0.9688 - val_loss: 0.0913
# Epoch 19/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9904 - loss: 0.0306 - val_accuracy: 0.9500 - val_loss: 0.1066
# Epoch 20/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9828 - loss: 0.0436 - val_accuracy: 0.9563 - val_loss: 0.1227
# Epoch 21/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9855 - loss: 0.0450 - val_accuracy: 0.9625 - val_loss: 0.0972
# Epoch 22/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9848 - loss: 0.0329 - val_accuracy: 0.9563 - val_loss: 0.1003
# Epoch 23/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9830 - loss: 0.0400 - val_accuracy: 0.9563 - val_loss: 0.0945
# Epoch 24/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9954 - loss: 0.0288 - val_accuracy: 0.9563 - val_loss: 0.1092
# Epoch 25/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9927 - loss: 0.0235 - val_accuracy: 0.9625 - val_loss: 0.1032
# Epoch 26/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9858 - loss: 0.0413 - val_accuracy: 0.9563 - val_loss: 0.0939
# Epoch 27/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9926 - loss: 0.0213 - val_accuracy: 0.9625 - val_loss: 0.1005
# Epoch 28/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9888 - loss: 0.0251 - val_accuracy: 0.9625 - val_loss: 0.0953
# Epoch 29/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9981 - loss: 0.0199 - val_accuracy: 0.9688 - val_loss: 0.0960
# Epoch 30/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9965 - loss: 0.0191 - val_accuracy: 0.9688 - val_loss: 0.1055

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
history_dict = history.history
loss_values = history_dict["loss"]
val_loss_values = history_dict["val_loss"]
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, "bo", label="Training loss")
plt.plot(epochs, val_loss_values, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.clf()
acc = history_dict["accuracy"]
val_acc = history_dict["val_accuracy"]
plt.plot(epochs, acc, "bo", label="Training acc")
plt.plot(epochs, val_acc, "b", label="Validation acc")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
# L2 규제 추가
from tensorflow.keras import regularizers

def build_model_overfit():
    model = keras.Sequential([
        layers.Dense(256, activation="relu"),
        layers.Dense(256, activation="relu"),
        layers.Dense(1, activation="sigmoid")  # 이진 값으로 변경
    ])
    model.compile(optimizer="rmsprop", loss="binary_crossentropy", metrics=["accuracy"]) # 손실함수는 이진함수로 넣고, 평가지표는 정확도로 함
    return model
